# %%
# %sql
describe history employees

# %%
# %sql
select *
from employees version as of 4

# %%
# %sql
select * from employees@v4

# %%
# %sql
delete from employees

# %%
# %sql
select * from employees

# %%
# %sql
restore table employees to version as of 5

# %%
# %sql
select * from employees

# %%
# %sql
describe history employees

# %% [markdown]
# Optimize command will reduce the files

# %%
# %sql
describe detail employees

# %%
# %sql
optimize employees
zorder by id

# %%
# %sql
describe detail employees

# %%
# %sql
describe history employees

# %%
# %sql
vacuum employees

# %%
# %sql
vacuum employees retain 0 hours

# %%
# %sql
SET spark.databricks.delta.retentionDurationCheck.enabled = false;

# %% [markdown]
# The command to alter retentionDurationCheck only works on the cluster, not serverless.
# This is not a recommended way to work with data retention anyways
