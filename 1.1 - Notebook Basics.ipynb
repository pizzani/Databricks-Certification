# %%
print("Hello world!")

# %%
# %sql
SELECT 'HELLO FROM SQL'

# %%
# %run ./Includes/Setup

# %%
print(full_name)

# %%
# %fs ls '/databricks-datasets'

# %%
dbutils.fs.help()

# %%
files = dbutils.fs.ls('/databricks-datasets')
display(files)
